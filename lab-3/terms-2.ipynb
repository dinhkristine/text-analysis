# %% [markdown]
# ## Lab 3

# %%
import pandas as pd 
import numpy as np 
from cytoolz import * 
from tqdm.auto import tqdm 
tqdm.pandas()

# %%
from dask.distributed import Client

client = Client("tcp://127.0.0.1:46513")
client
# Out:
# <Client: 'tcp://127.0.0.1:46513' processes=4 threads=4, memory=16.62 GB>

# %%
df = pd.read_parquet('s3://ling583/acl.parquet', storage_options = {'anon':True})

# %%
# distribute accross cluster 
import dask.dataframe as dd
import dask.bag as db

# %%
# divided into 60 article per piece
df = dd.from_pandas(df, npartitions = 100)
texts = df['text'].to_bag()

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm', exclude = ['parser', 'ner', 'lemmatizer', 'attribute_ruler'])

# %%
# extract candidate terms 

from spacy.matcher import Matcher

# %%
matcher = Matcher(nlp.vocab)
matcher.add('Term', [[{'TAG': {'IN': ['JJ', 'NN']}}, 
                     {'TAG': {'IN': ['JJ', 'NN', 'IN', 'HYPH']}, 'OP': '*'}, 
                     {'TAG': 'NN'}]])

# %%
def get_candidates(text):
    doc = nlp(text)
    spans = matcher(doc, as_spans = True)
    return [tuple(tok.norm_ for tok in span) for span in spans]

# %%
# define graph to get list of candidate per text  
# get the freq of the candidate
graph = texts.map(get_candidates) \
             .flatten() \
             .frequencies()

# %%
# %%time

candidates = graph.compute()
# Out:
# CPU times: user 10.3 s, sys: 1.46 s, total: 11.7 s
# Wall time: 5min 48s

# %%
candidates[:10]
# Out:
# [(('polynomial', 'time'), 234),
#  (('recognition', 'phase'), 17),
#  (('input', 'string'), 379),
#  (('spurious', 'ambiguity'), 148),
#  (('function', 'application'), 40),
#  (('relative', 'ordering'), 29),
#  (('considerable', 'interest'), 40),
#  (('large', 'number'), 1357),
#  (('same', 'function'), 26),
#  (('function', 'argument'), 5)]

# %%
# count freq and organize by len
from collections import defaultdict, Counter

# %%
freqs = defaultdict(Counter)
for c, f in candidates: 
    freqs[len(c)][c] = f

# %%
# given a candidate, loook at subterms 
# if the can is 5, then look for sub seq with 4, 3, 2 terms 

from nltk import ngrams

# %%
def get_subterms(term):
    k = len(term)
    for m in range(k-1, 1, -1):
        yield from ngrams(term, m)

# %%
from math import log2

# %%
def c_value(F, theta):
    
    termhood = Counter()
    longer = defaultdict(list)
    
    for k in sorted(F, reverse = True):
        for term in F[k]:
            if term in longer: 
                discount = sum(longer[term]) / len(longer[term])
            else: 
                discount = 0
            c = log2(k) * (F[k][term] - discount)
            if c > theta: 
                termhood[term] = c 
                for subterm in get_subterms(term):
                    if subterm in F[len(subterm)]:
                        longer[subterm].append(F[k][term])
    return termhood

# %%
# change theta to get more/less technical terms
terms = c_value(freqs, theta = 250)
# Out:
# Counter({('such', 'as', 'part', '-', 'of', '-', 'speech'): 269.50607251753,
#          ('part', '-', 'of', '-', 'speech', 'tagger'): 369.6496376031253,
#          ('part', '-', 'of', '-', 'speech', 'tagging'): 1067.5895127978374,
#          ('part', '-', 'of', '-', 'speech', 'tag'): 429.1037751197119,
#          ('sequence', '-', 'to', '-', 'sequence', 'model'): 392.91430010961574,
#          ('word', '-', 'to', '-', 'word'): 531.7215337292059,
#          ('part', '-', 'of', '-', 'speech'): 4935.258165683088,
#          ('word', '-', 'by', '-', 'word'): 297.20679614558236,
#          ('state', '-', 'ofthe', '-', 'art'): 1170.2517598232305,
#          ('tree', '-', 'to', '-', 'string'): 849.8256827287746,
#          ('-', 'fold', 'cross', '-', 'validation'): 652.4617946633488,
#          ('end', '-', 'to', '-', 'end'): 3171.7537776161366,
#          ('state', '-', 'of', '-', 'theart'): 1042.5457146044257,
#          ('tree', '-', 'to', '-', 'tree'): 383.1181356564148,
#          ('out', '-', 'of', '-', 'domain'): 262.37787472227194,
#          ('bag', '-', 'of', '-', 'word'): 255.41209043760983,
#          ('long', 'short', '-', 'term', 'memory'): 343.6453580433296,
#          ('sequence', '-', 'to', '-', 'sequence'): 993.785224611791,
#          ('context', '-', 'free', 'grammar'): 676.0,
#          ('predicate', '-', 'argument', 'structure'): 440.0,
#          ('right', '-', 'hand', 'side'): 618.0,
#          ('left', '-', 'hand', 'side'): 312.0,
#          ('many', 'natural', 'language', 'processing'): 286.0,
#          ('such', 'as', 'machine', 'translation'): 410.0,
#          ('log', '-', 'linear', 'model'): 838.0,
#          ('-', 'fold', 'cross', 'validation'): 892.0,
#          ('multi', '-', 'document', 'summarization'): 600.0,
#          ('inter', '-', 'annotator', 'agreement'): 1010.0,
#          ('multi', '-', 'class', 'classification'): 304.0,
#          ('semi', '-', 'supervised', 'learning'): 828.0,
#          ('multi', '-', 'task', 'learning'): 1112.0,
#          ('skip', '-', 'gram', 'model'): 286.0,
#          ('cross', '-', 'lingual', 'word'): 406.0,
#          ('cross', '-', 'entropy', 'loss'): 490.0,
#          ('pre', '-', 'trained', 'word'): 724.0,
#          ('encoder', '-', 'decoder', 'model'): 288.0,
#          ('natural', 'language', 'processing'): 2363.179088575244,
#          ('amount', 'of', 'information'): 256.7639251168273,
#          ('high', '-', 'level'): 1138.00307551779,
#          ('low', '-', 'level'): 613.3804877790874,
#          ('source', 'of', 'information'): 280.53836262764463,
#          ('phrase', '-', 'structure'): 297.9729501355773,
#          ('machine', 'translation', 'system'): 594.3609377704336,
#          ('first', '-', 'order'): 1031.8105879694726,
#          ('sentence', '-', 'level'): 2317.21517605433,
#          ('predicate', '-', 'argument'): 722.7429003288472,
#          ('general', '-', 'purpose'): 427.93987519471216,
#          ('natural', 'language', 'generation'): 508.7729627314911,
#          ('point', 'of', 'view'): 838.4451628814916,
#          ('multi', '-', 'word'): 261.51881261899075,
#          ('source', '-', 'language'): 264.6887376204331,
#          ('target', '-', 'language'): 288.4631751312504,
#          ('part', 'of', 'speech'): 1369.407600623079,
#          ('order', 'of', 'magnitude'): 355.03160016153896,
#          ('natural', 'language', 'understanding'): 450.1293502048083,
#          ('top', '-', 'down'): 266.2737001211542,
#          ('bottom', '-', 'up'): 299.5579126362985,
#          ('top', '-', 'level'): 453.2992752062506,
#          ('long', '-', 'range'): 461.2240877098564,
#          ('finite', '-', 'state'): 1011.2060754600976,
#          ('long', '-', 'distance'): 765.5368878483184,
#          ('phrase', '-', 'level'): 320.1624251456735,
#          ('verb', '-', 'object'): 258.3488876175484,
#          ('free', 'word', 'order'): 252.0090376146638,
#          ('real', '-', 'time'): 551.5669502509623,
#          ('pre', '-', 'processing'): 328.0872376492793,
#          ('shift', '-', 'reduce'): 277.3684376262023,
#          ('fine', '-', 'tune'): 440.6195752004814,
#          ('beam', '-', 'search'): 301.14287513701964,
#          ('word', 'sense', 'disambiguation'): 890.7489254052897,
#          ('word', 'co', '-'): 324.917312647837,
#          ('co', '-', 'occurrence'): 1030.2256254687516,
#          ('adjective', '-', 'noun'): 313.8225751427889,
#          ('trade', '-', 'off'): 672.0241003057702,
#          ('large', '-', 'scale'): 2301.3655510471185,
#          ('real', '-', 'world'): 1302.8391755927903,
#          ('high', '-', 'quality'): 1049.2451754774054,
#          ('statistical', 'machine', 'translation'): 1475.6000881713962,
#          ('low', '-', 'frequency'): 321.74738764639466,
#          ('n', '-', 'gram'): 2144.454263475724,
#          ('noun', '-', 'noun'): 305.8977626391831,
#          ('part', '-', 'ofspeech'): 351.86167516009664,
#          ('word', 'error', 'rate'): 404.1654376838948,
#          ('long', '-', 'term'): 570.5865002596162,
#          ('question', '-', 'answer'): 686.2887628122605,
#          ('set', 'of', 'candidate'): 507.18800023076994,
#          ('automatic', 'speech', 'recognition'): 296.3879876348562,
#          ('sub', '-', 'tree'): 293.21806263341387,
#          ('fan', '-', 'out'): 250.42407511394265,
#          ('wide', '-', 'coverage'): 296.3879876348562,
#          ('maximum', 'likelihood', 'estimation'): 307.4827251399043,
#          ('number', 'of', 'training'): 594.3609377704336,
#          ('such', 'as', 'word'): 361.3714501644236,
#          ('amount', 'of', 'training'): 546.8120627487989,
#          ('second', '-', 'order'): 710.0632003230779,
#          ('room', 'for', 'improvement'): 316.9925001442312,
#          ('word', '-', 'level'): 2209.4377260052916,
#          ('short', '-', 'term'): 263.1037751197119,
#          ('f', '-', 'measure'): 1665.795588257935,
#          ('log', '-', 'likelihood'): 1044.490287975242,
#          ('line', 'of', 'research'): 291.63310013269273,
#          ('partof', '-', 'speech'): 318.5774626449524,
#          ('low', '-', 'rank'): 342.3519001557697,
#          ('chinese', 'word', 'segmentation'): 515.1128127343758,
#          ('maximum', 'entropy', 'model'): 290.04813763197154,
#          ('source', '-', 'target'): 293.21806263341387,
#          ('set', 'of', 'training'): 278.9534001269235,
#          ('cross', '-', 'validation'): 424.76995019326984,
#          ('t', '-', 'test'): 752.8571878425491,
#          ('line', 'of', 'work'): 309.0676876406254,
#          ('character', '-', 'level'): 1332.9534631064923,
#          ('feed', '-', 'forward'): 621.3053002826932,
#          ('co', '-', 'reference'): 437.44965019903907,
#          ('-', 'processing', 'step'): 267.8586626218754,
#          ('back', '-', 'translation'): 285.2932501298081,
#          ('document', '-', 'level'): 1163.3624755293285,
#          ('gram', 'language', 'model'): 706.8932753216357,
#          ('top', '-', 'k'): 334.42708765216395,
#          ('natural', 'language', 'inference'): 288.4631751312504,
#          ('e', '-', 'step'): 316.9925001442312,
#          ('open', '-', 'source'): 484.99852522067374,
#          ('gold', '-', 'standard'): 569.001537758895,
#          ('open', '-', 'domain'): 722.7429003288472,
#          ('f', '-', 'score'): 2019.2422259187529,
#          ('semantic', 'role', 'labeling'): 879.6541879002416,
#          ('co', '-', 'training'): 413.67521268822173,
#          ('self', '-', 'training'): 676.7789878079336,
#          ('time', 'step', 't'): 350.2767126593755,
#          ('recurrent', 'neural', 'network'): 857.4647128901454,
#          ('stochastic', 'gradient', 'descent'): 578.511312763222,
#          ('f1', '-', 'score'): 508.7729627314911,
#          ('low', '-', 'resource'): 1046.075250475963,
#          ('hyper', '-', 'parameter'): 508.7729627314911,
#          ('sub', '-', 'word'): 516.6977752350969,
#          ('neural', 'network', 'model'): 464.3940127112987,
#          ('linear', '-', 'chain'): 266.2737001211542,
#          ('token', '-', 'level'): 523.0376252379815,
#          ('initial', 'learning', 'rate'): 348.6917501586543,
#          ('target', '-', 'side'): 570.5865002596162,
#          ('source', '-', 'side'): 656.1744752985586,
#          ('ground', '-', 'truth'): 781.38651285553,
#          ('skip', '-', 'gram'): 294.80302513413505,
#          ('pre', '-', 'training'): 454.8842377069718,
#          ('deep', 'neural', 'network'): 259.9338501182696,
#          ('convolutional', 'neural', 'network'): 451.7143127055295,
#          ('neural', 'machine', 'translation'): 775.0466628526453,
#          ('encoder', '-', 'decoder'): 919.2782504182705,
#          ('self', '-', 'attention'): 1155.4376630257227,
#          ('input', 'string'): 379.0,
#          ('large', 'number'): 1357.0,
#          ('argument', 'structure'): 264.0,
#          ('finite', 'set'): 339.0,
#          ('derivation', 'tree'): 421.0,
#          ('same', 'way'): 725.0,
#          ('time', 'complexity'): 512.0,
#          ('natural', 'language'): 4875.2,
#          ('language', 'processing'): 1191.5,
#          ('hand', 'side'): 430.5,
#          ('previous', 'work'): 3346.0,
#          ('syntactic', 'structure'): 808.0,
#          ('spoken', 'language'): 428.0,
#          ('same', 'type'): 295.0,
#          ('wide', 'variety'): 374.0,
#          ('recent', 'work'): 1042.0,
#          ('logical', 'form'): 937.0,
#          ('language', 'understanding'): 328.0,
#          ('syntactic', 'analysis'): 374.0,
#          ('speech', 'recognition'): 1254.0,
#          ('prepositional', 'phrase'): 360.0,
#          ('related', 'work'): 948.0,
#          ('such', 'information'): 282.0,
#          ('standard', 'deviation'): 507.0,
#          ('same', 'number'): 332.0,
#          ('head', 'noun'): 254.0,
#          ('test', 'set'): 3003.0,
#          ('novel', 'approach'): 384.0,
#          ('semantic', 'information'): 1101.0,
#          ('noun', 'phrase'): 1434.0,
#          ('exact', 'match'): 324.0,
#          ('success', 'rate'): 288.0,
#          ('next', 'section'): 978.0,
#          ('small', 'number'): 876.0,
#          ('computational', 'complexity'): 335.0,
#          ('data', 'structure'): 315.0,
#          ('parse', 'tree'): 2174.0,
#          ('same', 'word'): 391.0,
#          ('sentence', 'length'): 739.0,
#          ('other', 'hand'): 3012.0,
#          ('dependency', 'structure'): 604.0,
#          ('phrase', 'structure'): 567.0,
#          ('input', 'sentence'): 1453.0,
#          ('search', 'space'): 1128.0,
#          ('co', '-'): 2278.0,
#          ('machine', 'translation'): 4560.0,
#          ('translation', 'system'): 489.0,
#          ('parsing', 'model'): 344.0,
#          ('future', 'research'): 560.0,
#          ('previous', 'section'): 706.0,
#          ('relative', 'clause'): 296.0,
#          ('word', 'sense'): 643.0,
#          ('same', 'sentence'): 521.0,
#          ('head', 'word'): 647.0,
#          ('real', 'world'): 362.0,
#          ('knowledge', 'base'): 1467.0,
#          ('semantic', 'relation'): 369.0,
#          ('semantic', 'representation'): 735.0,
#          ('linguistic', 'information'): 380.0,
#          ('sub', '-'): 1111.5,
#          ('sentence', 'level'): 839.0,
#          ('semantic', 'content'): 292.0,
#          ('level', 'information'): 348.0,
#          ('pronoun', 'resolution'): 298.0,
#          ('contextual', 'information'): 883.0,
#          ('verb', 'phrase'): 277.0,
#          ('upper', 'bound'): 252.0,
#          ('large', 'amount'): 594.0,
#          ('discourse', 'structure'): 563.0,
#          ('average', 'number'): 614.0,
#          ('current', 'state'): 667.0,
#          ('speech', 'act'): 305.0,
#          ('full', 'model'): 397.0,
#          ('main', 'verb'): 311.0,
#          ('event', 'type'): 287.0,
#          ('domain', 'knowledge'): 301.0,
#          ('special', 'case'): 410.0,
#          ('future', 'work'): 2923.0,
#          ('surface', 'realization'): 322.0,
#          ('surface', 'form'): 410.0,
#          ('single', 'word'): 527.0,
#          ('-', 'word'): 526.4,
#          ('important', 'role'): 477.0,
#          ('same', 'time'): 1095.0,
#          ('cross', '-'): 523.5,
#          ('first', 'step'): 959.0,
#          ('decision', 'tree'): 565.0,
#          ('elementary', 'tree'): 367.0,
#          ('lexical', 'item'): 298.0,
#          ('long', 'distance'): 287.0,
#          ('auxiliary', 'tree'): 343.0,
#          ('root', 'node'): 637.0,
#          ('starting', 'point'): 381.0,
#          ('target', 'language'): 2370.0,
#          ('source', 'language'): 1547.0,
#          ('single', 'sentence'): 291.0,
#          ('english', 'sentence'): 414.0,
#          ('wide', 'range'): 771.0,
#          ('english', 'translation'): 552.0,
#          ('feature', 'structure'): 298.0,
#          ('tree', 'structure'): 599.0,
#          ('following', 'example'): 272.0,
#          ('first', 'sentence'): 399.0,
#          ('prior', 'knowledge'): 531.0,
#          ('unknown', 'word'): 470.0,
#          ('lexical', 'knowledge'): 299.0,
#          ('non', '-'): 709.0,
#          ('learning', 'process'): 416.0,
#          ('normal', 'form'): 260.0,
#          ('different', 'word'): 285.0,
#          ('text', 'generation'): 511.0,
#          ('feature', 'set'): 1111.0,
#          ('first', 'time'): 352.0,
#          ('source', 'code'): 293.0,
#          ('e', '-'): 447.0,
#          ('additional', 'information'): 489.0,
#          ('new', 'approach'): 256.0,
#          ('fair', 'comparison'): 365.0,
#          ('semantic', 'analysis'): 386.0,
#          ('maximum', 'number'): 388.0,
#          ('large', 'scale'): 474.0,
#          ('syntactic', 'information'): 950.0,
#          ('lexical', 'information'): 515.0,
#          ('generation', 'process'): 372.0,
#          ('beam', 'search'): 1215.0,
#          ('next', 'step'): 399.0,
#          ('same', 'entity'): 296.0,
#          ('evaluation', 'metric'): 590.0,
#          ('total', 'number'): 1510.0,
#          ('time', 'step'): 642.0,
#          ('generative', 'model'): 890.0,
#          ('generative', 'process'): 293.0,
#          ('dynamic', 'programming'): 947.0,
#          ('phrase', 'table'): 672.0,
#          ('computational', 'cost'): 296.0,
#          ('information', 'retrieval'): 1267.0,
#          ('statistical', 'significance'): 416.0,
#          ('first', 'stage'): 335.0,
#          ('word', 'pair'): 534.0,
#          ('training', 'corpus'): 2059.0,
#          ('training', 'set'): 3583.0,
#          ('text', 'corpus'): 344.0,
#          ('semantic', 'class'): 348.0,
#          ('basic', 'idea'): 364.0,
#          ('mutual', 'information'): 938.0,
#          ('similarity', 'measure'): 691.0,
#          ('joint', 'probability'): 358.0,
#          ('semantic', 'relatedness'): 474.0,
#          ('error', 'rate'): 1245.0,
#          ('similarity', 'score'): 478.0,
#          ('finite', 'state'): 357.0,
#          ('pseudo', '-'): 307.0,
#          ('dialog', 'system'): 681.0,
#          ('second', 'step'): 353.0,
#          ('tree', 't'): 324.0,
#          ('different', 'feature'): 279.0,
#          ('useful', 'information'): 343.0,
#          ('initial', 'state'): 292.0,
#          ('morphological', 'analysis'): 515.0,
#          ('input', 'text'): 473.0,
#          ('search', 'algorithm'): 395.0,
#          ('world', 'knowledge'): 363.0,
#          ('semantic', 'parser'): 439.0,
#          ('new', 'domain'): 311.0,
#          ('discourse', 'relation'): 434.0,
#          ('linguistic', 'knowledge'): 532.0,
#          ('re', '-'): 956.0,
#          ('semantic', 'role'): 580.0,
#          ('word', 'order'): 1417.0,
#          ('same', 'meaning'): 280.0,
#          ('e', 't'): 459.0,
#          ('next', 'word'): 402.0,
#          ('first', 'word'): 336.0,
#          ('input', 'word'): 277.0,
#          ('semantic', 'parsing'): 1109.0,
#          ('neural', 'network'): 3599.25,
#          ('scoring', 'function'): 542.0,
#          ('weight', 'matrix'): 297.0,
#          ('training', 'time'): 603.0,
#          ('target', 'word'): 1999.0,
#          ('statistical', 'model'): 379.0,
#          ('language', 'model'): 5236.0,
#          ('other', 'language'): 340.0,
#          ('sense', 'disambiguation'): 285.0,
#          ('word', 'level'): 539.0,
#          ('source', 'word'): 898.0,
#          ('source', 'sentence'): 1608.0,
#          ('target', 'sentence'): 783.0,
#          ('bilingual', 'dictionary'): 391.0,
#          ('english', 'word'): 571.0,
#          ('%', 'confidence'): 275.0,
#          ('word', 'frequency'): 316.0,
#          ('%', 'precision'): 371.0,
#          ('bilingual', 'corpus'): 333.0,
#          ('high', 'precision'): 538.0,
#          ('learning', 'method'): 390.0,
#          ('hidden', 'layer'): 632.0,
#          ('translation', 'task'): 459.0,
#          ('case', 'study'): 290.0,
#          ('error', 'detection'): 295.0,
#          ('different', 'language'): 255.0,
#          ('language', 'pair'): 598.0,
#          ('relative', 'frequency'): 313.0,
#          ('maximum', 'likelihood'): 420.0,
#          ('probabilistic', 'model'): 511.0,
#          ('t', 'j'): 395.0,
#          ('translation', 'performance'): 429.0,
#          ('source', 'text'): 462.0,
#          ('hierarchical', 'structure'): 306.0,
#          ('relevant', 'information'): 288.0,
#          ('semantic', 'similarity'): 1036.0,
#          ('high', 'accuracy'): 494.0,
#          ('large', 'corpus'): 606.0,
#          ('conditional', 'probability'): 808.0,
#          ('previous', 'research'): 379.0,
#          ('training', 'phase'): 275.0,
#          ('small', 'set'): 553.0,
#          ('language', 'modeling'): 1314.0,
#          ('same', 'set'): 371.0,
#          ('translation', 'model'): 1554.0,
#          ('word', 'sequence'): 702.0,
#          ('english', 'language'): 279.0,
#          ('current', 'word'): 385.0,
#          ('probability', 'distribution'): 1151.0,
#          ('uniform', 'distribution'): 360.0,
#          ('word', 'type'): 356.0,
#          ('good', 'performance'): 494.0,
#          ('%', 'recall'): 273.0,
#          ('overall', 'performance'): 545.0,
#          ('model', 'training'): 421.0,
#          ('high', 'performance'): 265.0,
#          ('input', 'sequence'): 515.0,
#          ('error', 'correction'): 342.0,
#          ('semantic', 'knowledge'): 338.0,
#          ('previous', 'state'): 317.0,
#          ('challenging', 'task'): 269.0,
#          ('time', 't'): 276.0,
#          ('local', 'context'): 513.0,
#          ('first', 'experiment'): 290.0,
#          ('content', 'word'): 264.0,
#          ('high', 'level'): 282.0,
#          ('relation', 'r'): 369.0,
#          ('%', 'accuracy'): 865.0,
#          ('significant', 'improvement'): 759.0,
#          ('meaning', 'representation'): 253.0,
#          ('user', 'interface'): 278.0,
#          ('dialog', 'manager'): 290.0,
#          ('dialog', 'history'): 320.0,
#          ('system', 'output'): 284.0,
#          ('temporal', 'relation'): 253.0,
#          ('training', 'process'): 471.0,
#          ('test', 'corpus'): 523.0,
#          ('overall', 'accuracy'): 266.0,
#          ('significant', 'difference'): 328.0,
#          ('data', 'set'): 533.0,
#          ('syntactic', 'parsing'): 444.0,
#          ('system', 'performance'): 374.0,
#          ('similarity', 'function'): 262.0,
#          ('query', 'expansion'): 358.0,
#          ('document', 'frequency'): 275.0,
#          ('term', 'frequency'): 269.0,
#          ('average', 'precision'): 337.0,
#          ('structural', 'information'): 277.0,
#          ('feature', 'extraction'): 384.0,
#          ('parameter', 'estimation'): 376.0,
#          ('raw', 'text'): 373.0,
#          ('training', 'algorithm'): 289.0,
#          ('original', 'sentence'): 370.0,
#          ('average', 'length'): 308.0,
#          ('vocabulary', 'size'): 693.0,
#          ('score', 'function'): 268.0,
#          ('%', 'improvement'): 326.0,
#          ('performance', 'improvement'): 292.0,
#          ('context', 'window'): 322.0,
#          ('feature', 'space'): 733.0,
#          ('training', 'dataset'): 301.0,
#          ('first', 'one'): 261.0,
#          ('feature', 'vector'): 1178.0,
#          ('training', 'procedure'): 458.0,
#          ('important', 'information'): 263.0,
#          ('supervised', 'learning'): 759.0,
#          ('training', 'example'): 302.0,
#          ('baseline', 'system'): 877.0,
#          ('large', 'set'): 336.0,
#          ('parallel', 'text'): 285.0,
#          ('classification', 'task'): 946.0,
#          ('single', 'model'): 293.0,
#          ('dependency', 'tree'): 1266.0,
#          ('word', 'similarity'): 618.0,
#          ('morphological', 'analyzer'): 372.0,
#          ('word', 'translation'): 357.0,
#          ('dependency', 'relation'): 503.0,
#          ('gram', 'model'): 481.0,
#          ('error', 'analysis'): 541.0,
#          ('syntactic', 'dependency'): 270.0,
#          ('regular', 'expression'): 254.0,
#          ('lexical', 'cohesion'): 271.0,
#          ('human', 'performance'): 299.0,
#          ('extraction', 'task'): 283.0,
#          ('automatic', 'evaluation'): 643.0,
#          ('clustering', 'algorithm'): 321.0,
#          ('objective', 'function'): 1360.0,
#          ('correct', 'answer'): 569.0,
#          ('small', 'amount'): 408.0,
#          ('classification', 'problem'): 514.0,
#          ('probability', 'mass'): 339.0,
#          ('distribution', 'p'): 279.0,
#          ('unsupervised', 'learning'): 325.0,
#          ('distributional', 'similarity'): 509.0,
#          ('maximum', 'entropy'): 691.0,
#          ('linear', 'combination'): 409.0,
#          ('log', 'likelihood'): 284.0,
#          ('high', 'quality'): 576.0,
#          ('average', 'accuracy'): 258.0,
#          ('information', 'extraction'): 960.0,
#          ('vector', 'space'): 944.0,
#          ('vector', 'representation'): 599.0,
#          ('weighted', 'sum'): 334.0,
#          ('prediction', 'task'): 333.0,
#          ('learning', 'rate'): 815.0,
#          ('context', 'vector'): 680.0,
#          ('grammar', 'induction'): 323.0,
#          ('learning', 'algorithm'): 684.0,
#          ('response', 'generation'): 263.0,
#          ('optimization', 'problem'): 472.0,
#          ('trigram', 'model'): 284.0,
#          ('word', 'segmentation'): 1113.0,
#          ('spoken', 'dialog'): 417.0,
#          ('window', 'size'): 676.0,
#          ('source', 'phrase'): 281.0,
#          ('learning', 'approach'): 453.0,
#          ('candidate', 'answer'): 256.0,
#          ('chinese', 'word'): 251.0,
#          ('probability', 'p'): 383.0,
#          ('ground', 'truth'): 877.0,
#          ('sentence', 'representation'): 310.0,
#          ('context', 'information'): 570.0,
#          ('novel', 'method'): 255.0,
#          ('model', 'selection'): 265.0,
#          ('dimensional', 'vector'): 254.0,
#          ('linear', 'model'): 329.0,
#          ('new', 'state'): 342.0,
#          ('random', 'walk'): 254.0,
#          ('learning', 'model'): 289.0,
#          ('tag', 'sequence'): 270.0,
#          ('translation', 'quality'): 1208.0,
#          ('model', 'score'): 253.0,
#          ('baseline', 'model'): 723.0,
#          ('output', 'layer'): 500.0,
#          ('graphical', 'model'): 284.0,
#          ('development', 'set'): 1808.0,
#          ('posterior', 'probability'): 388.0,
#          ('confidence', 'score'): 318.0,
#          ('text', 'summarization'): 351.0,
#          ('same', 'topic'): 286.0,
#          ('dot', 'product'): 356.0,
#          ('regression', 'model'): 448.0,
#          ('edit', 'distance'): 646.0,
#          ('tagging', 'accuracy'): 290.0,
#          ('_', 'b'): 636.0,
#          ('machine', 'learning'): 1505.0,
#          ('feature', 'representation'): 355.0,
#          ('dialog', 'act'): 597.0,
#          ('reading', 'comprehension'): 406.0,
#          ('source', 'domain'): 715.0,
#          ('context', 'word'): 309.0,
#          ('supervised', 'training'): 266.0,
#          ('word', 'form'): 301.0,
#          ('linear', 'regression'): 269.0,
#          ('model', 'performance'): 359.0,
#          ('parallel', 'corpus'): 1177.0,
#          ('word', 'alignment'): 2001.0,
#          ('sentence', 'pair'): 778.0,
#          ('gold', 'standard'): 1168.0,
#          ('search', 'engine'): 778.0,
#          ('background', 'knowledge'): 329.0,
#          ('document', 'collection'): 277.0,
#          ('classification', 'accuracy'): 498.0,
#          ('prior', 'work'): 905.0,
#          ('channel', 'model'): 374.0,
#          ('alignment', 'model'): 500.0,
#          ('dependency', 'graph'): 299.0,
#          ('beam', 'size'): 504.0,
#          ('content', 'selection'): 294.0,
#          ('manual', 'annotation'): 293.0,
#          ('posterior', 'distribution'): 258.0,
#          ('batch', 'size'): 568.0,
#          ('text', 'categorization'): 336.0,
#          ('logistic', 'regression'): 726.0,
#          ('weight', 'vector'): 551.0,
#          ('document', 'classification'): 251.0,
#          ('binary', 'classification'): 554.0,
#          ('document', 'd'): 378.0,
#          ('word', 'vector'): 445.0,
#          ('external', 'knowledge'): 398.0,
#          ('grid', 'search'): 283.0,
#          ('coreference', 'resolution'): 1073.0,
#          ('error', 'reduction'): 494.0,
#          ('sequence', 'model'): 271.0,
#          ('p', 'r'): 268.0,
#          ('translation', 'probability'): 338.0,
#          ('bi', '-'): 368.0,
#          ('dependency', 'parser'): 738.0,
#          ('annotation', 'scheme'): 498.0,
#          ('reference', 'translation'): 302.0,
#          ('class', 'label'): 279.0,
#          ('source', 'side'): 469.0,
#          ('target', 'side'): 584.0,
#          ('i', 't'): 1251.0,
#          ('entity', 'type'): 477.0,
#          ('%', 'f'): 268.0,
#          ('entity', 'recognition'): 755.0,
#          ('active', 'learning'): 721.0,
#          ('knowledge', 'graph'): 393.0,
#          ('base', 'model'): 272.0,
#          ('dependency', 'parse'): 388.0,
#          ('experimental', 'setup'): 307.0,
#          ('web', 'search'): 396.0,
#          ('news', 'article'): 283.0,
#          ('feature', 'engineering'): 369.0,
#          ('relation', 'extraction'): 1489.0,
#          ('pos', 'tagging'): 284.0,
#          ('feature', 'selection'): 648.0,
#          ('validation', 'set'): 609.0,
#          ('topic', 'model'): 677.0,
#          ('dialog', 'state'): 275.0,
#          ('topic', 'modeling'): 436.0,
#          ('word', 'representation'): 391.0,
#          ('dependency', 'parsing'): 1726.0,
#          ('target', 'domain'): 1290.0,
#          ('attention', 'model'): 406.0,
#          ('feature', 'function'): 317.0,
#          ('activation', 'function'): 360.0,
#          ('document', 'summarization'): 317.0,
#          ('reinforcement', 'learning'): 722.0,
#          ('hierarchical', 'phrase'): 289.0,
#          ('semantic', 'space'): 386.0,
#          ('cosine', 'similarity'): 1253.0,
#          ('topic', 'distribution'): 403.0,
#          ('joint', 'model'): 639.0,
#          ('arg', 'max'): 300.0,
#          ('latent', 'variable'): 433.0,
#          ('classification', 'model'): 253.0,
#          ('extractive', 'summarization'): 322.0,
#          ('summarization', 'task'): 252.0,
#          ('text', 'classification'): 846.0,
#          ('sentence', 'selection'): 295.0,
#          ('-', 'training'): 398.0,
#          ('human', 'evaluation'): 746.0,
#          ('support', 'vector'): 337.0,
#          ('art', 'performance'): 698.0,
#          ('relation', 'type'): 396.0,
#          ('phrase', 'translation'): 354.0,
#          ('domain', 'adaptation'): 1234.0,
#          ('r', 't'): 281.0,
#          ('loss', 'function'): 1182.0,
#          ('test', 'time'): 593.0,
#          ('open', 'source'): 314.0,
#          ('document', 'level'): 275.0,
#          ('large', 'margin'): 378.0,
#          ('tree', 'kernel'): 511.0,
#          ('p', 't'): 265.0,
#          ('relation', 'classification'): 427.0,
#          ('negative', 'sentiment'): 267.0,
#          ('c', 'j'): 267.0,
#          ('event', 'extraction'): 478.0,
#          ('event', 'detection'): 312.0,
#          ('r', 'd'): 413.0,
#          ('strong', 'baseline'): 259.0,
#          ('new', 'dataset'): 294.0,
#          ('c', 't'): 261.0,
#          ('state', 'h'): 296.0,
#          ('hidden', 'state'): 944.0,
#          ('sentiment', 'classification'): 1144.0,
#          ('sentiment', 'analysis'): 1509.0,
#          ('sentiment', 'polarity'): 324.0,
#          ('entity', 'pair'): 293.0,
#          ('sequence', 'labeling'): 754.0,
#          ('phrase', 'pair'): 510.0,
#          ('sentence', 'compression'): 411.0,
#          ('system', 'combination'): 270.0,
#          ('textual', 'entailment'): 341.0,
#          ('structured', 'prediction'): 314.0,
#          ('training', 'objective'): 333.0,
#          ('f1', 'score'): 462.0,
#          ('h', 't'): 577.0,
#          ('dev', 'set'): 255.0,
#          ('opinion', 'mining'): 257.0,
#          ('transfer', 'learning'): 266.0,
#          ('abstractive', 'summarization'): 255.0,
#          ('distant', 'supervision'): 567.0,
#          ('deep', 'learning'): 773.0,
#          ('neural', 'model'): 387.0,
#          ('representation', 'learning'): 324.0,
#          ('negative', 'sampling'): 270.0,
#          ('attention', 'mechanism'): 1470.0,
#          ('adversarial', 'training'): 327.0})

# %%
# terms from top of the list 
for t, c in terms.most_common(20):
    print(f'{c:8.2f} {freqs[len(t)][t]:4d} {" ".join(t)}')
# Out:
#  5236.00 5682 language model
#  4935.26 2330 part - of - speech
#  4875.20 5388 natural language
#  4560.00 5060 machine translation
#  3599.25 3920 neural network
#  3583.00 3583 training set
#  3346.00 3346 previous work
#  3171.75 1366 end - to - end
#  3012.00 3012 other hand
#  3003.00 3003 test set
#  2923.00 2923 future work
#  2370.00 2370 target language
#  2363.18 1634 natural language processing
#  2317.22 1462 sentence - level
#  2301.37 1452 large - scale
#  2278.00 2626 co -
#  2209.44 1394 word - level
#  2174.00 2174 parse tree
#  2144.45 1353 n - gram
#  2059.00 2059 training corpus

# %%
for t, c in tail(20, terms.most_common()):
    print(f'{c:8.2f} {freqs[len(t)][t]:4d} {" ".join(t)}')
# Out:
#   256.00  256 candidate answer
#   255.41  110 bag - of - word
#   255.00  255 different language
#   255.00  255 novel method
#   255.00  255 dev set
#   255.00  255 abstractive summarization
#   254.00  254 head noun
#   254.00  254 regular expression
#   254.00  254 dimensional vector
#   254.00  254 random walk
#   253.00  253 meaning representation
#   253.00  253 temporal relation
#   253.00  253 model score
#   253.00  253 classification model
#   252.01  159 free word order
#   252.00  252 upper bound
#   252.00  252 summarization task
#   251.00  576 chinese word
#   251.00  251 document classification
#   250.42  158 fan - out

# %%
with open('terms.txt', 'w') as f: 
    for term in terms: 
        print(' '.join(term), file = f)
